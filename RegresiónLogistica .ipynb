# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler

# Importar los datos
df = pd.read_csv("manufacturing_defect_dataset_OK .csv", sep=';', engine='python')

# %%
df.head()
# Out:
#    ProductionVolume  ProductionCost  SupplierQuality  DeliveryDelay  \
# 0               202    13175.403780        86.648534              1
# 1               535    19770.046090        86.310664              4
# 2               960    19060.821000        82.132472              0
# 3               370     5647.606037        87.335966              5
# 4               206     7472.222236        81.989893              3
#
#    DefectRate  QualityScore  MaintenanceHours  DowntimePercentage  \
# 0    3.121492     63.463494                 9            0.052343
# 1    0.819531     83.697818                20            4.908328
# 2    4.514504     90.350550                 1            2.464923
# 3    0.638524     67.628690                 8            4.692476
# 4    3.867784     82.728334                 9            2.746726
#
#    InventoryTurnover  StockoutRate  WorkerProductivity  SafetyIncidents  \
# 0           8.630515      0.081322           85.042379                0
# 1           9.296598      0.038486           99.657443                7
# 2           5.097486      0.002887           92.819264                2
# 3           3.577616      0.055331           96.887013                8
# 4           6.851709      0.068047           88.315554                7
#
#    EnergyConsumption  EnergyEfficiency  AdditiveProcessTime  \
# 0        2419.616785          0.468947             5.551639
# 1        3915.566713          0.119485             9.080754
# 2        3392.385362          0.496392             6.562827
# 3        4652.400275          0.183125             8.097496
# 4        1581.630332          0.263507             6.406154
#
#    AdditiveMaterialCost  DefectStatus
# 0            236.439301             1
# 1            353.957631             1
# 2            396.189402             1
# 3            164.135870             1
# 4            365.708964             1

# %%
import pandas as pd

# Importar los datos
df = pd.read_csv("manufacturing_defect_dataset_OK .csv", sep=';', engine='python')

# %%
df.head()
# Out:
#    ProductionVolume  ProductionCost  SupplierQuality  DeliveryDelay  \
# 0               202    13175.403780        86.648534              1
# 1               535    19770.046090        86.310664              4
# 2               960    19060.821000        82.132472              0
# 3               370     5647.606037        87.335966              5
# 4               206     7472.222236        81.989893              3
#
#    DefectRate  QualityScore  MaintenanceHours  DowntimePercentage  \
# 0    3.121492     63.463494                 9            0.052343
# 1    0.819531     83.697818                20            4.908328
# 2    4.514504     90.350550                 1            2.464923
# 3    0.638524     67.628690                 8            4.692476
# 4    3.867784     82.728334                 9            2.746726
#
#    InventoryTurnover  StockoutRate  WorkerProductivity  SafetyIncidents  \
# 0           8.630515      0.081322           85.042379                0
# 1           9.296598      0.038486           99.657443                7
# 2           5.097486      0.002887           92.819264                2
# 3           3.577616      0.055331           96.887013                8
# 4           6.851709      0.068047           88.315554                7
#
#    EnergyConsumption  EnergyEfficiency  AdditiveProcessTime  \
# 0        2419.616785          0.468947             5.551639
# 1        3915.566713          0.119485             9.080754
# 2        3392.385362          0.496392             6.562827
# 3        4652.400275          0.183125             8.097496
# 4        1581.630332          0.263507             6.406154
#
#    AdditiveMaterialCost  DefectStatus
# 0            236.439301             1
# 1            353.957631             1
# 2            396.189402             1
# 3            164.135870             1
# 4            365.708964             1

# %%
print("Tipos de datos por columna:")
print(df.dtypes)
# Out:
# Tipos de datos por columna:
# ProductionVolume          int64
# ProductionCost          float64
# SupplierQuality         float64
# DeliveryDelay             int64
# DefectRate              float64
# QualityScore            float64
# MaintenanceHours          int64
# DowntimePercentage      float64
# InventoryTurnover       float64
# StockoutRate            float64
# WorkerProductivity      float64
# SafetyIncidents           int64
# EnergyConsumption       float64
# EnergyEfficiency        float64
# AdditiveProcessTime     float64
# AdditiveMaterialCost    float64
# DefectStatus              int64
# dtype: object

# %%
print("Valores nulos por columna:")
print(df.isnull().sum())
# Out:
# Valores nulos por columna:
# ProductionVolume        0
# ProductionCost          0
# SupplierQuality         0
# DeliveryDelay           0
# DefectRate              0
# QualityScore            0
# MaintenanceHours        0
# DowntimePercentage      0
# InventoryTurnover       0
# StockoutRate            0
# WorkerProductivity      0
# SafetyIncidents         0
# EnergyConsumption       0
# EnergyEfficiency        0
# AdditiveProcessTime     0
# AdditiveMaterialCost    0
# DefectStatus            0
# dtype: int64

# %%
df.describe()
# Out:
#        ProductionVolume  ProductionCost  SupplierQuality  DeliveryDelay  \
# count       3240.000000     3240.000000      3240.000000    3240.000000
# mean         548.523148    12423.018476        89.833290       2.558951
# std          262.402073     4308.051904         5.759143       1.705804
# min          100.000000     5000.174521        80.004820       0.000000
# 25%          322.000000     8728.829280        84.869219       1.000000
# 50%          549.000000    12405.204660        89.704861       3.000000
# 75%          775.250000    16124.462427        94.789936       4.000000
# max          999.000000    19993.365550        99.989214       5.000000
#
#         DefectRate  QualityScore  MaintenanceHours  DowntimePercentage  \
# count  3240.000000   3240.000000       3240.000000         3240.000000
# mean      2.749116     80.134272         11.476543            2.501373
# std       1.310154     11.611750          6.872684            1.443684
# min       0.500710     60.010098          0.000000            0.001665
# 25%       1.598033     70.103420          5.750000            1.264597
# 50%       2.708775     80.265312         12.000000            2.465151
# 75%       3.904533     90.353822         17.000000            3.774861
# max       4.998529     99.996993         23.000000            4.997591
#
#        InventoryTurnover  StockoutRate  WorkerProductivity  SafetyIncidents  \
# count        3240.000000   3240.000000         3240.000000      3240.000000
# mean            6.019662      0.050878           90.040115         4.591667
# std             2.329791      0.028797            5.723600         2.896313
# min             2.001611      0.000002           80.004960         0.000000
# 25%             3.983249      0.026200           85.180203         2.000000
# 50%             6.022389      0.051837           90.125743         5.000000
# 75%             8.050222      0.075473           95.050838         7.000000
# max             9.998577      0.099997           99.996786         9.000000
#
#        EnergyConsumption  EnergyEfficiency  AdditiveProcessTime  \
# count        3240.000000       3240.000000          3240.000000
# mean         2988.494453          0.299776             5.472098
# std          1153.420820          0.116400             2.598212
# min          1000.720156          0.100238             1.000151
# 25%          1988.140274          0.200502             3.228507
# 50%          2996.822302          0.297470             5.437134
# 75%          3984.788299          0.402659             7.741006
# max          4997.074741          0.499500             9.999749
#
#        AdditiveMaterialCost  DefectStatus
# count           3240.000000   3240.000000
# mean             299.515479      0.840432
# std              116.379905      0.366261
# min              100.211138      0.000000
# 25%              194.922058      1.000000
# 50%              299.728918      1.000000
# 75%              403.178283      1.000000
# max              499.982782      1.000000

# %%
print("Distribución de la variable 'DefectStatus':")
print(df['DefectStatus'].value_counts(normalize=True))
# Out:
# Distribución de la variable 'DefectStatus':
# DefectStatus
# 1    0.840432
# 0    0.159568
# Name: proportion, dtype: float64

# %%
import matplotlib.pyplot as plt

df.hist(bins=30, figsize=(15, 12))
plt.tight_layout()
plt.show()

# %%
import seaborn as sns

variables = ['DefectRate', 'DowntimePercentage', 'StockoutRate']
for var in variables:
    sns.boxplot(x=df[var])
    plt.title(f'Diagrama de caja: {var}')
    plt.show()

# %%
plt.figure(figsize=(14, 10))
sns.heatmap(df.corr(), annot=False, cmap="coolwarm")
plt.title("Matriz de correlación")
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3240 entries, 0 to 3239
# Data columns (total 17 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ProductionVolume      3240 non-null   int64
#  1   ProductionCost        3240 non-null   float64
#  2   SupplierQuality       3240 non-null   float64
#  3   DeliveryDelay         3240 non-null   int64
#  4   DefectRate            3240 non-null   float64
#  5   QualityScore          3240 non-null   float64
#  6   MaintenanceHours      3240 non-null   int64
#  7   DowntimePercentage    3240 non-null   float64
#  8   InventoryTurnover     3240 non-null   float64
#  9   StockoutRate          3240 non-null   float64
#  10  WorkerProductivity    3240 non-null   float64
#  11  SafetyIncidents       3240 non-null   int64
#  12  EnergyConsumption     3240 non-null   float64
#  13  EnergyEfficiency      3240 non-null   float64
#  14  AdditiveProcessTime   3240 non-null   float64
#  15  AdditiveMaterialCost  3240 non-null   float64
#  16  DefectStatus          3240 non-null   int64
# dtypes: float64(12), int64(5)
# memory usage: 430.4 KB

# %%
df['DefectStatus'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='DefectStatus'>

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(14, 10))
sns.heatmap(df.corr(), annot=False, cmap="coolwarm")
plt.title("Matriz de correlación")
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(14, 10))
sns.heatmap(df.corr(), annot=True, fmt=".2f", cmap="coolwarm", square=True)
plt.title("Matriz de correlación entre variables")
plt.show()

# %%
# Comprobar si hay duplicados
df.duplicated().sum()
# Out:
# 0

# %%
X = df.drop("DefectStatus", axis=1)
y = df["DefectStatus"]

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    test_size=0.2,
    stratify=y,
    random_state=42
)

# 3. Verificación
print("Proporción de clases en el conjunto de entrenamiento:")
print(y_train.value_counts(normalize=True))

print("\nProporción de clases en el conjunto de prueba:")
print(y_test.value_counts(normalize=True))
# Out:
# Proporción de clases en el conjunto de entrenamiento:
# DefectStatus
# 1    0.840278
# 0    0.159722
# Name: proportion, dtype: float64
#
# Proporción de clases en el conjunto de prueba:
# DefectStatus
# 1    0.841049
# 0    0.158951
# Name: proportion, dtype: float64

# %%
print(X_train.shape, X_test.shape)
# Out:
# (2592, 16) (648, 16)

# %%
# Escalar los datos
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV

# %%
logreg = LogisticRegression(max_iter=5000, solver='liblinear', random_state=42)

# %%
param_grid = {
    'C': [0.1, 1, 10]
}

# %%
grid_search = GridSearchCV(logreg, param_grid, scoring='roc_auc', cv=5, n_jobs=-1)
grid_search.fit(X_train_scaled, y_train)
# Out:
# GridSearchCV(cv=5,
#              estimator=LogisticRegression(max_iter=5000, random_state=42,
#                                           solver='liblinear'),
#              n_jobs=-1, param_grid={'C': [0.1, 1, 10]}, scoring='roc_auc')

# %%
best_logreg = grid_search.best_estimator_
print("Mejores hiperparámetros encontrados:", grid_search.best_params_)
# Out:
# Mejores hiperparámetros encontrados: {'C': 1}

# %%
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score, roc_curve

y_pred = best_logreg.predict(X_test_scaled)
y_proba = best_logreg.predict_proba(X_test_scaled)[:, 1]

print("\nInforme de clasificación:")
print(classification_report(y_test, y_pred))
print("ROC-AUC:", roc_auc_score(y_test, y_proba))
print("Matriz de confusión:\n", confusion_matrix(y_test, y_pred))
# Out:
# Informe de clasificación:
#               precision    recall  f1-score   support
#
#            0       0.71      0.38      0.49       103
#            1       0.89      0.97      0.93       545
#
#     accuracy                           0.88       648
#    macro avg       0.80      0.67      0.71       648
# weighted avg       0.86      0.88      0.86       648
#
# ROC-AUC: 0.7960630622606217
# Matriz de confusión:
#  [[ 39  64]
#  [ 16 529]]

# %%
fpr, tpr, _ = roc_curve(y_test, y_proba)
plt.figure(figsize=(8,6))
plt.plot(fpr, tpr, label=f"ROC-AUC = {roc_auc_score(y_test, y_proba):.2f}")
plt.plot([0, 1], [0, 1], 'k--')
plt.xlabel("Tasa de falsos positivos")
plt.ylabel("Tasa de verdaderos positivos")
plt.title("Curva ROC - Regresión Logística")
plt.legend()
plt.grid()
plt.show()

# %%
# Definir la matriz de confusión 
conf_matrix = np.array([[39, 64],
                        [16, 529]])


df_cm_simple = pd.DataFrame(conf_matrix,
                            index=["0", "1"],
                            columns=["0", "1"])

# Dibujar 
plt.figure(figsize=(6.5, 6))
sns.heatmap(df_cm_simple, annot=True, fmt='d', cmap='Reds', cbar=True,
            linewidths=0.5, linecolor='gray', annot_kws={"size": 12})
plt.title("Matriz de Confusión - Regresión Logística", fontsize=14, pad=12)
plt.xlabel("Predicted", fontsize=12)
plt.ylabel("Actual", fontsize=12)
plt.xticks(fontsize=11)
plt.yticks(fontsize=11, rotation=0)
plt.tight_layout()
plt.show()

# %%
from sklearn.metrics import precision_recall_curve

precision, recall, thresholds = precision_recall_curve(y_test, y_proba)

plt.plot(thresholds, precision[:-1], label='Precision')
plt.plot(thresholds, recall[:-1], label='Recall')
plt.xlabel('Umbral')
plt.ylabel('Métrica')
plt.title('Precisión y recall según el umbral de decisión')
plt.legend()
plt.grid()
plt.show()

# %%
from sklearn.metrics import f1_score


y_train_pred = model.predict(X_train)
f1_train = f1_score(y_train, y_train_pred)

# Predicción sobre test
y_test_pred = model.predict(X_test)
f1_test = f1_score(y_test, y_test_pred)

print("F1-score en entrenamiento:", f1_train)
print("F1-score en test:", f1_test)
# Out:
# F1-score en entrenamiento: 0.8539553752535497
# F1-score en test: 0.8389057750759878

# %%
conf_matrix = np.array([[51, 52],
                        [29, 516]])


df_cm_simple = pd.DataFrame(conf_matrix,
                            index=["0", "1"],
                            columns=["0", "1"])


plt.figure(figsize=(6.5, 6))
sns.heatmap(df_cm_simple, annot=True, fmt='d', cmap='Reds', cbar=True,
            linewidths=0.5, linecolor='gray', annot_kws={"size": 12})
plt.title("Matriz de Confusión - Regresión Logística (Umbral=0.6)", fontsize=14, pad=12)
plt.xlabel("Predicted", fontsize=12)
plt.ylabel("Actual", fontsize=12)
plt.xticks(fontsize=11)
plt.yticks(fontsize=11, rotation=0)
plt.tight_layout()
plt.show()

# %%
from sklearn.model_selection import train_test_split

# Separar por clase
X_class_0 = X[y == 0]
X_class_1 = X[y == 1]
y_class_0 = y[y == 0]
y_class_1 = y[y == 1]

# Seleccionar el mismo número de muestras para test
n_test = min(len(X_class_0), len(X_class_1), 100)  

X_0_test, X_0_remain, y_0_test, y_0_remain = train_test_split(X_class_0, y_class_0, test_size=(len(X_class_0)-n_test), random_state=42)
X_1_test, X_1_remain, y_1_test, y_1_remain = train_test_split(X_class_1, y_class_1, test_size=(len(X_class_1)-n_test), random_state=42)

# Crear conjunto de test final (balanceado)
X_test_bal = pd.concat([X_0_test, X_1_test])
y_test_bal = pd.concat([y_0_test, y_1_test])

# %%
n_iter = len(X_1_remain) // len(X_0_remain)
bloques_X1 = np.array_split(X_1_remain, n_iter)
bloques_y1 = np.array_split(y_1_remain, n_iter)
# Out:
# C:\Users\crist\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:59: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)
# C:\Users\crist\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:59: FutureWarning: 'Series.swapaxes' is deprecated and will be removed in a future version. Please use 'Series.transpose' instead.
#   return bound(*args, **kwds)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report
import numpy as np

modelos = []
predicciones = []

for i in range(n_iter):
    # Crear conjunto balanceado para esta iteración
    X_train_iter = pd.concat([X_0_remain, bloques_X1[i]])
    y_train_iter = pd.concat([y_0_remain, bloques_y1[i]])

    # Entrenar 
    model = LogisticRegression(max_iter=5000, solver='liblinear', random_state=42)
    model.fit(X_train_iter, y_train_iter)

    
    pred = model.predict(X_test_bal)
    predicciones.append(pred)
    modelos.append(model)

# %%
from scipy.stats import mode

# Convertir lista a matriz 
predicciones_matrix = np.array(predicciones)

# Votación por mayoría
y_pred_final = mode(predicciones_matrix, axis=0).mode.flatten()

# %%
from sklearn.metrics import classification_report, confusion_matrix

print("Informe de clasificación:\n", classification_report(y_test_bal, y_pred_final))
print("Matriz de confusión:\n", confusion_matrix(y_test_bal, y_pred_final))
# Out:
# Informe de clasificación:
#                precision    recall  f1-score   support
#
#            0       0.75      0.72      0.73       100
#            1       0.73      0.76      0.75       100
#
#     accuracy                           0.74       200
#    macro avg       0.74      0.74      0.74       200
# weighted avg       0.74      0.74      0.74       200
#
# Matriz de confusión:
#  [[72 28]
#  [24 76]]

# %%
conf_matrix = np.array([[72, 28],
                        [24, 76]])


df_cm_simple = pd.DataFrame(conf_matrix,
                            index=["0", "1"],
                            columns=["0", "1"])


plt.figure(figsize=(6.5, 6))
sns.heatmap(df_cm_simple, annot=True, fmt='d', cmap='Reds', cbar=True,
            linewidths=0.5, linecolor='gray', annot_kws={"size": 12})
plt.title("Matriz de Confusión - Regresión Logística ", fontsize=14, pad=12)
plt.xlabel("Predicted", fontsize=12)
plt.ylabel("Actual", fontsize=12)
plt.xticks(fontsize=11)
plt.yticks(fontsize=11, rotation=0)
plt.tight_layout()
plt.show()

# %%
# Regresión logística con umbral ajustado
y_train_prob = model.predict_proba(X_train)[:, 1]
y_test_prob = model.predict_proba(X_test)[:, 1]

y_train_pred = (y_train_prob > 0.6).astype(int)
y_test_pred = (y_test_prob > 0.6).astype(int)

f1_train = f1_score(y_train, y_train_pred)
f1_test = f1_score(y_test, y_test_pred)

print("F1-score ajustado (train):", f1_train)
print("F1-score ajustado (test):", f1_test)
# Out:
# F1-score ajustado (train): 0.7904839145715058
# F1-score ajustado (test): 0.7581699346405228

# %%
import matplotlib.pyplot as plt

# F1-scores obtenidos
modelos = ['Regresión Logística (umbral 0.6)']
f1_train = [0.79]
f1_test = [0.76]

x = range(len(modelos))

plt.figure(figsize=(6, 4))
plt.bar(x, f1_train, width=0.4, label='Train', align='center')
plt.bar([i + 0.4 for i in x], f1_test, width=0.4, label='Test', align='center')
plt.xticks([i + 0.2 for i in x], modelos, rotation=15)
plt.ylabel('F1-score')
plt.title('Comparación F1-score en Train y Test')
plt.ylim(0, 1)
plt.legend()
plt.tight_layout()
plt.grid(axis='y')
plt.show()
